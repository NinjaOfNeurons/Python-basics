# %% [markdown]
# ## Top 30

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    "employee_id": [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
    "name": ["Alice", "Bob", "Charlie", "David", "Eva",
             "Frank", "Grace", "Henry", "Ivy", "Jack"],
    "department": ["IT", "HR", "IT", "Finance", "HR",
                   "IT", "Finance", "IT", "HR", "Finance"],
    "age": [25, 32, 28, 45, 29, 35, 41, 26, np.nan, 38],
    "salary": [60000, 52000, 75000, 90000, 58000,
               72000, 85000, np.nan, 62000, 95000],
    "experience": [2, 8, 4, 18, 5, 10, 15, 3, 6, 12],
    "city": ["Delhi", "Mumbai", "Delhi", "Pune", "Mumbai",
             "Delhi", "Pune", "Delhi", "Mumbai", "Delhi"],
    "joining_date": [
        "2022-01-15", "2018-03-10", "2021-06-20", "2006-07-01",
        "2020-02-15", "2016-11-10", "2009-05-20", "2023-01-05",
        "2019-08-12", "2014-04-25"
    ],
    "performance_score": [8.5, 7.2, 9.1, 8.8, 6.9,
                          9.5, 7.8, 8.2, np.nan, 9.0]
})

df["joining_date"] = pd.to_datetime(df["joining_date"])

# %%
df
# Out:
#    employee_id     name department   age   salary  experience    city  \
# 0          101    Alice         IT  25.0  60000.0           2   Delhi
# 1          102      Bob         HR  32.0  52000.0           8  Mumbai
# 2          103  Charlie         IT  28.0  75000.0           4   Delhi
# 3          104    David    Finance  45.0  90000.0          18    Pune
# 4          105      Eva         HR  29.0  58000.0           5  Mumbai
# 5          106    Frank         IT  35.0  72000.0          10   Delhi
# 6          107    Grace    Finance  41.0  85000.0          15    Pune
# 7          108    Henry         IT  26.0      NaN           3   Delhi
# 8          109      Ivy         HR   NaN  62000.0           6  Mumbai
# 9          110     Jack    Finance  38.0  95000.0          12   Delhi
#
#   joining_date  performance_score
# 0   2022-01-15                8.5
# 1   2018-03-10                7.2
# 2   2021-06-20                9.1
# 3   2006-07-01                8.8
# ...

# %%
df[["name","department","salary"]]
# Out:
#       name department   salary
# 0    Alice         IT  60000.0
# 1      Bob         HR  52000.0
# 2  Charlie         IT  75000.0
# 3    David    Finance  90000.0
# 4      Eva         HR  58000.0
# 5    Frank         IT  72000.0
# 6    Grace    Finance  85000.0
# 7    Henry         IT      NaN
# 8      Ivy         HR  62000.0
# 9     Jack    Finance  95000.0

# %%
df[df["salary"]>7000]
# Out:
#    employee_id     name department   age   salary  experience    city  \
# 0          101    Alice         IT  25.0  60000.0           2   Delhi
# 1          102      Bob         HR  32.0  52000.0           8  Mumbai
# 2          103  Charlie         IT  28.0  75000.0           4   Delhi
# 3          104    David    Finance  45.0  90000.0          18    Pune
# 4          105      Eva         HR  29.0  58000.0           5  Mumbai
# 5          106    Frank         IT  35.0  72000.0          10   Delhi
# 6          107    Grace    Finance  41.0  85000.0          15    Pune
# 8          109      Ivy         HR   NaN  62000.0           6  Mumbai
# 9          110     Jack    Finance  38.0  95000.0          12   Delhi
#
#   joining_date  performance_score
# 0   2022-01-15                8.5
# 1   2018-03-10                7.2
# 2   2021-06-20                9.1
# 3   2006-07-01                8.8
# 4   2020-02-15                6.9
# 5   2016-11-10                9.5
# ...

# %%
df[(df["salary"]>7000) & (df["department"] == "IT")]
# Out:
#    employee_id     name department   age   salary  experience   city  \
# 0          101    Alice         IT  25.0  60000.0           2  Delhi
# 2          103  Charlie         IT  28.0  75000.0           4  Delhi
# 5          106    Frank         IT  35.0  72000.0          10  Delhi
#
#   joining_date  performance_score
# 0   2022-01-15                8.5
# 2   2021-06-20                9.1
# 5   2016-11-10                9.5

# %%
df.loc[2:5][["name","salary"]]
# Out:
#       name   salary
# 2  Charlie  75000.0
# 3    David  90000.0
# 4      Eva  58000.0
# 5    Frank  72000.0

# %%
df.iloc[2:6,1:4]
# Out:
#       name department   age
# 2  Charlie         IT  28.0
# 3    David    Finance  45.0
# 4      Eva         HR  29.0
# 5    Frank         IT  35.0

# %%
df
# Out:
#    employee_id     name department   age   salary  experience    city  \
# 0          101    Alice         IT  25.0  60000.0           2   Delhi
# 1          102      Bob         HR  32.0  52000.0           8  Mumbai
# 2          103  Charlie         IT  28.0  75000.0           4   Delhi
# 3          104    David    Finance  45.0  90000.0          18    Pune
# 4          105      Eva         HR  29.0  58000.0           5  Mumbai
# 5          106    Frank         IT  35.0  72000.0          10   Delhi
# 6          107    Grace    Finance  41.0  85000.0          15    Pune
# 7          108    Henry         IT  26.0      NaN           3   Delhi
# 8          109      Ivy         HR   NaN  62000.0           6  Mumbai
# 9          110     Jack    Finance  38.0  95000.0          12   Delhi
#
#   joining_date  performance_score
# 0   2022-01-15                8.5
# 1   2018-03-10                7.2
# 2   2021-06-20                9.1
# 3   2006-07-01                8.8
# ...

# %%
df.sort_values("salary",ascending=False)
# Out:
#    employee_id     name department   age   salary  experience    city  \
# 9          110     Jack    Finance  38.0  95000.0          12   Delhi
# 3          104    David    Finance  45.0  90000.0          18    Pune
# 6          107    Grace    Finance  41.0  85000.0          15    Pune
# 2          103  Charlie         IT  28.0  75000.0           4   Delhi
# 5          106    Frank         IT  35.0  72000.0          10   Delhi
# 8          109      Ivy         HR   NaN  62000.0           6  Mumbai
# 0          101    Alice         IT  25.0  60000.0           2   Delhi
# 4          105      Eva         HR  29.0  58000.0           5  Mumbai
# 1          102      Bob         HR  32.0  52000.0           8  Mumbai
# 7          108    Henry         IT  26.0      NaN           3   Delhi
#
#   joining_date  performance_score
# 9   2014-04-25                9.0
# 3   2006-07-01                8.8
# 6   2009-05-20                7.8
# 2   2021-06-20                9.1
# ...

# %%
df.sort_values(["department","salary"], ascending=[False,True])
# Out:
#    employee_id     name department   age   salary  experience    city  \
# 0          101    Alice         IT  25.0  60000.0           2   Delhi
# 5          106    Frank         IT  35.0  72000.0          10   Delhi
# 2          103  Charlie         IT  28.0  75000.0           4   Delhi
# 7          108    Henry         IT  26.0      NaN           3   Delhi
# 1          102      Bob         HR  32.0  52000.0           8  Mumbai
# 4          105      Eva         HR  29.0  58000.0           5  Mumbai
# 8          109      Ivy         HR   NaN  62000.0           6  Mumbai
# 6          107    Grace    Finance  41.0  85000.0          15    Pune
# 3          104    David    Finance  45.0  90000.0          18    Pune
# 9          110     Jack    Finance  38.0  95000.0          12   Delhi
#
#   joining_date  performance_score
# 0   2022-01-15                8.5
# 5   2016-11-10                9.5
# 2   2021-06-20                9.1
# 7   2023-01-05                8.2
# ...

# %%
df
# Out:
#    employee_id     name department   age   salary  experience    city  \
# 0          101    Alice         IT  25.0  60000.0           2   Delhi
# 1          102      Bob         HR  32.0  52000.0           8  Mumbai
# 2          103  Charlie         IT  28.0  75000.0           4   Delhi
# 3          104    David    Finance  45.0  90000.0          18    Pune
# 4          105      Eva         HR  29.0  58000.0           5  Mumbai
# 5          106    Frank         IT  35.0  72000.0          10   Delhi
# 6          107    Grace    Finance  41.0  85000.0          15    Pune
# 7          108    Henry         IT  26.0      NaN           3   Delhi
# 8          109      Ivy         HR   NaN  62000.0           6  Mumbai
# 9          110     Jack    Finance  38.0  95000.0          12   Delhi
#
#   joining_date  performance_score
# 0   2022-01-15                8.5
# 1   2018-03-10                7.2
# 2   2021-06-20                9.1
# 3   2006-07-01                8.8
# ...

# %%
df.isna().sum()
# Out:
# employee_id          0
# name                 0
# department           0
# age                  1
# salary               1
# experience           0
# city                 0
# joining_date         0
# performance_score    1
# dtype: int64

# %%
df["salary"] = df["salary"].fillna(df["salary"].mean()).round(1)

# %%
df
# Out:
#    employee_id     name department   age   salary  experience    city  \
# 0          101    Alice         IT  25.0  60000.0           2   Delhi
# 1          102      Bob         HR  32.0  52000.0           8  Mumbai
# 2          103  Charlie         IT  28.0  75000.0           4   Delhi
# 3          104    David    Finance  45.0  90000.0          18    Pune
# 4          105      Eva         HR  29.0  58000.0           5  Mumbai
# 5          106    Frank         IT  35.0  72000.0          10   Delhi
# 6          107    Grace    Finance  41.0  85000.0          15    Pune
# 7          108    Henry         IT  26.0      NaN           3   Delhi
# 8          109      Ivy         HR   NaN  62000.0           6  Mumbai
# 9          110     Jack    Finance  38.0  95000.0          12   Delhi
#
#   joining_date  performance_score
# 0   2022-01-15                8.5
# 1   2018-03-10                7.2
# 2   2021-06-20                9.1
# 3   2006-07-01                8.8
# ...

# %%
df.dropna(subset="salary")
# Out:
#    employee_id     name department   age   salary  experience    city  \
# 0          101    Alice         IT  25.0  60000.0           2   Delhi
# 1          102      Bob         HR  32.0  52000.0           8  Mumbai
# 2          103  Charlie         IT  28.0  75000.0           4   Delhi
# 3          104    David    Finance  45.0  90000.0          18    Pune
# 4          105      Eva         HR  29.0  58000.0           5  Mumbai
# 5          106    Frank         IT  35.0  72000.0          10   Delhi
# 6          107    Grace    Finance  41.0  85000.0          15    Pune
# 8          109      Ivy         HR   NaN  62000.0           6  Mumbai
# 9          110     Jack    Finance  38.0  95000.0          12   Delhi
#
#   joining_date  performance_score
# 0   2022-01-15                8.5
# 1   2018-03-10                7.2
# 2   2021-06-20                9.1
# 3   2006-07-01                8.8
# 4   2020-02-15                6.9
# 5   2016-11-10                9.5
# ...

# %%
df
# Out:
#    employee_id     name department   age   salary  experience    city  \
# 0          101    Alice         IT  25.0  60000.0           2   Delhi
# 1          102      Bob         HR  32.0  52000.0           8  Mumbai
# 2          103  Charlie         IT  28.0  75000.0           4   Delhi
# 3          104    David    Finance  45.0  90000.0          18    Pune
# 4          105      Eva         HR  29.0  58000.0           5  Mumbai
# 5          106    Frank         IT  35.0  72000.0          10   Delhi
# 6          107    Grace    Finance  41.0  85000.0          15    Pune
# 7          108    Henry         IT  26.0      NaN           3   Delhi
# 8          109      Ivy         HR   NaN  62000.0           6  Mumbai
# 9          110     Jack    Finance  38.0  95000.0          12   Delhi
#
#   joining_date  performance_score  salary_1
# 0   2022-01-15                8.5   60000.0
# 1   2018-03-10                7.2   52000.0
# 2   2021-06-20                9.1   75000.0
# ...

# %%
df.groupby("department")["salary"].mean().round(2)
# Out:
# department
# Finance    90000.00
# HR         57333.33
# IT         69000.00
# Name: salary, dtype: float64

# %%
df.groupby("department").agg(
    average_Salary = ("salary", "mean"),
    count_emp =("salary", "count"),
    max_salary = ("salary", "max")
)
# Out:
#             average_Salary  count_emp  max_salary
# department
# Finance       90000.000000          3     95000.0
# HR            57333.333333          3     62000.0
# IT            69000.000000          3     75000.0

# %%
df
# Out:
#    employee_id     name department   age   salary  experience    city  \
# 0          101    Alice         IT  25.0  60000.0           2   Delhi
# 1          102      Bob         HR  32.0  52000.0           8  Mumbai
# 2          103  Charlie         IT  28.0  75000.0           4   Delhi
# 3          104    David    Finance  45.0  90000.0          18    Pune
# 4          105      Eva         HR  29.0  58000.0           5  Mumbai
# 5          106    Frank         IT  35.0  72000.0          10   Delhi
# 6          107    Grace    Finance  41.0  85000.0          15    Pune
# 7          108    Henry         IT  26.0      NaN           3   Delhi
# 8          109      Ivy         HR   NaN  62000.0           6  Mumbai
# 9          110     Jack    Finance  38.0  95000.0          12   Delhi
#
#   joining_date  performance_score  salary_1
# 0   2022-01-15                8.5   60000.0
# 1   2018-03-10                7.2   52000.0
# 2   2021-06-20                9.1   75000.0
# ...

# %%
df.groupby("city").agg(
    avg_salary = ("salary", "mean"),
    min_salary=("salary", "min"),
    max_salary=("salary", "max"),
    avg_exp=("experience", "mean")


)
# Out:
#           avg_salary  min_salary  max_salary    avg_exp
# city
# Delhi   75500.000000     60000.0     95000.0   6.200000
# Mumbai  57333.333333     52000.0     62000.0   6.333333
# Pune    87500.000000     85000.0     90000.0  16.500000

# %%
# df.groupby("department")["employee_id"].count()
# total = df.count()
df["department"].value_counts(normalize=True)*100
# Out:
# department
# IT         40.0
# HR         30.0
# Finance    30.0
# Name: proportion, dtype: float64

# %%
df["salary_in_lakhs"] = df["salary"]/ 100000

# %%
df
# Out:
#    employee_id     name department   age   salary  experience    city  \
# 0          101    Alice         IT  25.0  60000.0           2   Delhi
# 1          102      Bob         HR  32.0  52000.0           8  Mumbai
# 2          103  Charlie         IT  28.0  75000.0           4   Delhi
# 3          104    David    Finance  45.0  90000.0          18    Pune
# 4          105      Eva         HR  29.0  58000.0           5  Mumbai
# 5          106    Frank         IT  35.0  72000.0          10   Delhi
# 6          107    Grace    Finance  41.0  85000.0          15    Pune
# 7          108    Henry         IT  26.0      NaN           3   Delhi
# 8          109      Ivy         HR   NaN  62000.0           6  Mumbai
# 9          110     Jack    Finance  38.0  95000.0          12   Delhi
#
#   joining_date  performance_score  salary_1  salary_in_lakhs
# 0   2022-01-15                8.5   60000.0             0.60
# 1   2018-03-10                7.2   52000.0             0.52
# ...

# %%
df["senior"] = df["experience"]>=10

# %%
df
# Out:
#    employee_id     name department   age   salary  experience    city  \
# 0          101    Alice         IT  25.0  60000.0           2   Delhi
# 1          102      Bob         HR  32.0  52000.0           8  Mumbai
# 2          103  Charlie         IT  28.0  75000.0           4   Delhi
# 3          104    David    Finance  45.0  90000.0          18    Pune
# 4          105      Eva         HR  29.0  58000.0           5  Mumbai
# 5          106    Frank         IT  35.0  72000.0          10   Delhi
# 6          107    Grace    Finance  41.0  85000.0          15    Pune
# 7          108    Henry         IT  26.0      NaN           3   Delhi
# 8          109      Ivy         HR   NaN  62000.0           6  Mumbai
# 9          110     Jack    Finance  38.0  95000.0          12   Delhi
#
#   joining_date  performance_score  salary_1  salary_in_lakhs  senior
# 0   2022-01-15                8.5   60000.0             0.60   False
# ...

# %%
import numpy as np


df["salary_level"] = np.where(
                                df["salary"] > 80000,
                                "High",
                                "Normal"
                                         )


df
# Out:
#    employee_id     name department   age   salary  experience    city  \
# 0          101    Alice         IT  25.0  60000.0           2   Delhi
# 1          102      Bob         HR  32.0  52000.0           8  Mumbai
# 2          103  Charlie         IT  28.0  75000.0           4   Delhi
# 3          104    David    Finance  45.0  90000.0          18    Pune
# 4          105      Eva         HR  29.0  58000.0           5  Mumbai
# 5          106    Frank         IT  35.0  72000.0          10   Delhi
# 6          107    Grace    Finance  41.0  85000.0          15    Pune
# 7          108    Henry         IT  26.0      NaN           3   Delhi
# 8          109      Ivy         HR   NaN  62000.0           6  Mumbai
# 9          110     Jack    Finance  38.0  95000.0          12   Delhi
#
#   joining_date  performance_score  salary_1  salary_in_lakhs  senior  \
# 0   2022-01-15                8.5   60000.0             0.60   False
# ...

# %%
df["age_cat"] = df["age"].apply(
    lambda x: "Young" if x < 30 else "Experienced"
)

# %%
df
# Out:
#    employee_id     name department   age   salary  experience    city  \
# 0          101    Alice         IT  25.0  60000.0           2   Delhi
# 1          102      Bob         HR  32.0  52000.0           8  Mumbai
# 2          103  Charlie         IT  28.0  75000.0           4   Delhi
# 3          104    David    Finance  45.0  90000.0          18    Pune
# 4          105      Eva         HR  29.0  58000.0           5  Mumbai
# 5          106    Frank         IT  35.0  72000.0          10   Delhi
# 6          107    Grace    Finance  41.0  85000.0          15    Pune
# 7          108    Henry         IT  26.0      NaN           3   Delhi
# 8          109      Ivy         HR   NaN  62000.0           6  Mumbai
# 9          110     Jack    Finance  38.0  95000.0          12   Delhi
#
#   joining_date  performance_score  salary_1  salary_in_lakhs  senior  \
# 0   2022-01-15                8.5   60000.0             0.60   False
# ...

# %%
df[df["name"].str.startswith("A")]
# Out:
#    employee_id   name department   age   salary  experience   city  \
# 0          101  Alice         IT  25.0  60000.0           2  Delhi
#
#   joining_date  performance_score  salary_1  salary_in_lakhs  senior  \
# 0   2022-01-15                8.5   60000.0              0.6   False
#
#   salary_level age_cat
# 0       Normal   Young

# %%
df[df["city"].str.contains("Delhi")]
# Out:
#    employee_id     name department   age   salary  experience   city  \
# 0          101    Alice         IT  25.0  60000.0           2  Delhi
# 2          103  Charlie         IT  28.0  75000.0           4  Delhi
# 5          106    Frank         IT  35.0  72000.0          10  Delhi
# 7          108    Henry         IT  26.0      NaN           3  Delhi
# 9          110     Jack    Finance  38.0  95000.0          12  Delhi
#
#   joining_date  performance_score  salary_1  salary_in_lakhs  senior  \
# 0   2022-01-15                8.5   60000.0             0.60   False
# 2   2021-06-20                9.1   75000.0             0.75   False
# 5   2016-11-10                9.5   72000.0             0.72    True
# 7   2023-01-05                8.2       NaN              NaN   False
# 9   2014-04-25                9.0   95000.0             0.95    True
#
#   salary_level      age_cat
# 0       Normal        Young
# 2       Normal        Young
# 5       Normal  Experienced
# ...

# %%
df["name"].str.upper()
# Out:
# 0      ALICE
# 1        BOB
# 2    CHARLIE
# 3      DAVID
# 4        EVA
# 5      FRANK
# 6      GRACE
# 7      HENRY
# 8        IVY
# 9       JACK
# Name: name, dtype: str

# %%
df
# Out:
#    employee_id     name department   age   salary  experience    city  \
# 0          101    Alice         IT  25.0  60000.0           2   Delhi
# 1          102      Bob         HR  32.0  52000.0           8  Mumbai
# 2          103  Charlie         IT  28.0  75000.0           4   Delhi
# 3          104    David    Finance  45.0  90000.0          18    Pune
# 4          105      Eva         HR  29.0  58000.0           5  Mumbai
# 5          106    Frank         IT  35.0  72000.0          10   Delhi
# 6          107    Grace    Finance  41.0  85000.0          15    Pune
# 7          108    Henry         IT  26.0      NaN           3   Delhi
# 8          109      Ivy         HR   NaN  62000.0           6  Mumbai
# 9          110     Jack    Finance  38.0  95000.0          12   Delhi
#
#   joining_date  performance_score  salary_1  salary_in_lakhs  senior  \
# 0   2022-01-15                8.5   60000.0             0.60   False
# ...

# %% [markdown]
# ### Date operations

# %% [markdown]
# ##### joining Yearly

# %%
df["joining_yearly"] = df["joining_date"].dt.year
df
# Out:
#    employee_id     name department   age   salary  experience    city  \
# 0          101    Alice         IT  25.0  60000.0           2   Delhi
# 1          102      Bob         HR  32.0  52000.0           8  Mumbai
# 2          103  Charlie         IT  28.0  75000.0           4   Delhi
# 3          104    David    Finance  45.0  90000.0          18    Pune
# 4          105      Eva         HR  29.0  58000.0           5  Mumbai
# 5          106    Frank         IT  35.0  72000.0          10   Delhi
# 6          107    Grace    Finance  41.0  85000.0          15    Pune
# 7          108    Henry         IT  26.0      NaN           3   Delhi
# 8          109      Ivy         HR   NaN  62000.0           6  Mumbai
# 9          110     Jack    Finance  38.0  95000.0          12   Delhi
#
#   joining_date  performance_score  salary_1  salary_in_lakhs  senior  \
# 0   2022-01-15                8.5   60000.0             0.60   False
# ...

# %%
df["month"]= df["joining_date"].dt.month

# %%
df
# Out:
#    employee_id     name department   age   salary  experience    city  \
# 0          101    Alice         IT  25.0  60000.0           2   Delhi
# 1          102      Bob         HR  32.0  52000.0           8  Mumbai
# 2          103  Charlie         IT  28.0  75000.0           4   Delhi
# 3          104    David    Finance  45.0  90000.0          18    Pune
# 4          105      Eva         HR  29.0  58000.0           5  Mumbai
# 5          106    Frank         IT  35.0  72000.0          10   Delhi
# 6          107    Grace    Finance  41.0  85000.0          15    Pune
# 7          108    Henry         IT  26.0      NaN           3   Delhi
# 8          109      Ivy         HR   NaN  62000.0           6  Mumbai
# 9          110     Jack    Finance  38.0  95000.0          12   Delhi
#
#   joining_date  performance_score  salary_1  salary_in_lakhs  senior  \
# 0   2022-01-15                8.5   60000.0             0.60   False
# ...

# %%
df[df["joining_yearly"] > 2020]
# Out:
#    employee_id     name department   age   salary  experience   city  \
# 0          101    Alice         IT  25.0  60000.0           2  Delhi
# 2          103  Charlie         IT  28.0  75000.0           4  Delhi
# 7          108    Henry         IT  26.0      NaN           3  Delhi
#
#   joining_date  performance_score  salary_1  salary_in_lakhs  senior  \
# 0   2022-01-15                8.5   60000.0             0.60   False
# 2   2021-06-20                9.1   75000.0             0.75   False
# 7   2023-01-05                8.2       NaN              NaN   False
#
#   salary_level age_cat  joining_yearly  month
# 0       Normal   Young            2022      1
# 2       Normal   Young            2021      6
# 7       Normal   Young            2023      1

# %%
df
# Out:
#    employee_id     name department   age   salary  experience    city  \
# 0          101    Alice         IT  25.0  60000.0           2   Delhi
# 1          102      Bob         HR  32.0  52000.0           8  Mumbai
# 2          103  Charlie         IT  28.0  75000.0           4   Delhi
# 3          104    David    Finance  45.0  90000.0          18    Pune
# 4          105      Eva         HR  29.0  58000.0           5  Mumbai
# 5          106    Frank         IT  35.0  72000.0          10   Delhi
# 6          107    Grace    Finance  41.0  85000.0          15    Pune
# 7          108    Henry         IT  26.0      NaN           3   Delhi
# 8          109      Ivy         HR   NaN  62000.0           6  Mumbai
# 9          110     Jack    Finance  38.0  95000.0          12   Delhi
#
#   joining_date  performance_score  salary_1  salary_in_lakhs  senior  \
# 0   2022-01-15                8.5   60000.0             0.60   False
# ...

# %% [markdown]
# ## find Duplicate

# %%
df[df.duplicated("city")]
# Out:
#    employee_id     name department   age   salary  experience    city  \
# 2          103  Charlie         IT  28.0  75000.0           4   Delhi
# 4          105      Eva         HR  29.0  58000.0           5  Mumbai
# 5          106    Frank         IT  35.0  72000.0          10   Delhi
# 6          107    Grace    Finance  41.0  85000.0          15    Pune
# 7          108    Henry         IT  26.0      NaN           3   Delhi
# 8          109      Ivy         HR   NaN  62000.0           6  Mumbai
# 9          110     Jack    Finance  38.0  95000.0          12   Delhi
#
#   joining_date  performance_score  salary_1  salary_in_lakhs  senior  \
# 2   2021-06-20                9.1   75000.0             0.75   False
# 4   2020-02-15                6.9   58000.0             0.58   False
# 5   2016-11-10                9.5   72000.0             0.72    True
# 6   2009-05-20                7.8   85000.0             0.85    True
# ...

# %%
df.drop_duplicates("employee_id")
# Out:
#    employee_id     name department   age   salary  experience    city  \
# 0          101    Alice         IT  25.0  60000.0           2   Delhi
# 1          102      Bob         HR  32.0  52000.0           8  Mumbai
# 2          103  Charlie         IT  28.0  75000.0           4   Delhi
# 3          104    David    Finance  45.0  90000.0          18    Pune
# 4          105      Eva         HR  29.0  58000.0           5  Mumbai
# 5          106    Frank         IT  35.0  72000.0          10   Delhi
# 6          107    Grace    Finance  41.0  85000.0          15    Pune
# 7          108    Henry         IT  26.0      NaN           3   Delhi
# 8          109      Ivy         HR   NaN  62000.0           6  Mumbai
# 9          110     Jack    Finance  38.0  95000.0          12   Delhi
#
#   joining_date  performance_score  salary_1  salary_in_lakhs  senior  \
# 0   2022-01-15                8.5   60000.0             0.60   False
# ...

# %%
df.rename(
    columns={
    "employee_id":"id",
    "performance_score":"performance"
})
# Out:
#     id     name department   age   salary  experience    city joining_date  \
# 0  101    Alice         IT  25.0  60000.0           2   Delhi   2022-01-15
# 1  102      Bob         HR  32.0  52000.0           8  Mumbai   2018-03-10
# 2  103  Charlie         IT  28.0  75000.0           4   Delhi   2021-06-20
# 3  104    David    Finance  45.0  90000.0          18    Pune   2006-07-01
# 4  105      Eva         HR  29.0  58000.0           5  Mumbai   2020-02-15
# 5  106    Frank         IT  35.0  72000.0          10   Delhi   2016-11-10
# 6  107    Grace    Finance  41.0  85000.0          15    Pune   2009-05-20
# 7  108    Henry         IT  26.0      NaN           3   Delhi   2023-01-05
# 8  109      Ivy         HR   NaN  62000.0           6  Mumbai   2019-08-12
# 9  110     Jack    Finance  38.0  95000.0          12   Delhi   2014-04-25
#
#    performance  salary_1  salary_in_lakhs  senior salary_level      age_cat  \
# ...

# %%
dept = pd.DataFrame({
    "department": ["IT", "HR", "Finance"],
    "manager": ["John", "Sarah", "Mike"]
})

# %%
df.merge(
    dept,
    left_on="department",
    right_on="department",
    how="left"


)
# Out:
#    employee_id     name department   age   salary  experience    city  \
# 0          101    Alice         IT  25.0  60000.0           2   Delhi
# 1          102      Bob         HR  32.0  52000.0           8  Mumbai
# 2          103  Charlie         IT  28.0  75000.0           4   Delhi
# 3          104    David    Finance  45.0  90000.0          18    Pune
# 4          105      Eva         HR  29.0  58000.0           5  Mumbai
# 5          106    Frank         IT  35.0  72000.0          10   Delhi
# 6          107    Grace    Finance  41.0  85000.0          15    Pune
# 7          108    Henry         IT  26.0      NaN           3   Delhi
# 8          109      Ivy         HR   NaN  62000.0           6  Mumbai
# 9          110     Jack    Finance  38.0  95000.0          12   Delhi
#
#   joining_date  performance_score  salary_1  salary_in_lakhs  senior  \
# 0   2022-01-15                8.5   60000.0             0.60   False
# ...

# %% [markdown]
# ## Concatination

# %%
new_employees = pd.DataFrame({
    "employee_id": [111, 112],
    "name": ["Kate", "Leo"],
    "department": ["IT", "HR"],
    "salary": [70000, 55000]
})

# %%
new_employees
# Out:
#    employee_id  name department  salary
# 0          111  Kate         IT   70000
# 1          112   Leo         HR   55000

# %%
pd.concat([df,new_employees],ignore_index=True)
# Out:
#     employee_id     name department   age   salary  experience    city  \
# 0           101    Alice         IT  25.0  60000.0         2.0   Delhi
# 1           102      Bob         HR  32.0  52000.0         8.0  Mumbai
# 2           103  Charlie         IT  28.0  75000.0         4.0   Delhi
# 3           104    David    Finance  45.0  90000.0        18.0    Pune
# 4           105      Eva         HR  29.0  58000.0         5.0  Mumbai
# 5           106    Frank         IT  35.0  72000.0        10.0   Delhi
# 6           107    Grace    Finance  41.0  85000.0        15.0    Pune
# 7           108    Henry         IT  26.0      NaN         3.0   Delhi
# 8           109      Ivy         HR   NaN  62000.0         6.0  Mumbai
# 9           110     Jack    Finance  38.0  95000.0        12.0   Delhi
# 10          111     Kate         IT   NaN  70000.0         NaN     NaN
# 11          112      Leo         HR   NaN  55000.0         NaN     NaN
#
# ...

# %%
df
# Out:
#    employee_id     name department   age   salary  experience    city  \
# 0          101    Alice         IT  25.0  60000.0           2   Delhi
# 1          102      Bob         HR  32.0  52000.0           8  Mumbai
# 2          103  Charlie         IT  28.0  75000.0           4   Delhi
# 3          104    David    Finance  45.0  90000.0          18    Pune
# 4          105      Eva         HR  29.0  58000.0           5  Mumbai
# 5          106    Frank         IT  35.0  72000.0          10   Delhi
# 6          107    Grace    Finance  41.0  85000.0          15    Pune
# 7          108    Henry         IT  26.0      NaN           3   Delhi
# 8          109      Ivy         HR   NaN  62000.0           6  Mumbai
# 9          110     Jack    Finance  38.0  95000.0          12   Delhi
#
#   joining_date  performance_score  salary_1  salary_in_lakhs  senior  \
# 0   2022-01-15                8.5   60000.0             0.60   False
# ...

# %%
df.sort_values("salary",ascending=False).iloc[0]
# Out:
# employee_id                          110
# name                                Jack
# department                       Finance
# age                                 38.0
# salary                           95000.0
# experience                            12
# city                               Delhi
# joining_date         2014-04-25 00:00:00
# performance_score                    9.0
# salary_1                         95000.0
# salary_in_lakhs                     0.95
# senior                              True
# salary_level                        High
# age_cat                      Experienced
# joining_yearly                      2014
# month                                  4
# Name: 9, dtype: object

# %%
df.loc[df["salary"].idxmax()]
# Out:
# employee_id                          110
# name                                Jack
# department                       Finance
# age                                 38.0
# salary                           95000.0
# experience                            12
# city                               Delhi
# joining_date         2014-04-25 00:00:00
# performance_score                    9.0
# salary_1                         95000.0
# salary_in_lakhs                     0.95
# senior                              True
# salary_level                        High
# age_cat                      Experienced
# joining_yearly                      2014
# month                                  4
# Name: 9, dtype: object

# %% [markdown]
# ### 3 largest

# %%
df.sort_values("salary",ascending=False).head(3)
# Out:
#    employee_id   name department   age   salary  experience   city  \
# 9          110   Jack    Finance  38.0  95000.0          12  Delhi
# 3          104  David    Finance  45.0  90000.0          18   Pune
# 6          107  Grace    Finance  41.0  85000.0          15   Pune
#
#   joining_date  performance_score  salary_1  salary_in_lakhs  senior  \
# 9   2014-04-25                9.0   95000.0             0.95    True
# 3   2006-07-01                8.8   90000.0             0.90    True
# 6   2009-05-20                7.8   85000.0             0.85    True
#
#   salary_level      age_cat  joining_yearly  month
# 9         High  Experienced            2014      4
# 3         High  Experienced            2006      7
# 6         High  Experienced            2009      5

# %%
df.nlargest(3, "salary")
# Out:
#    employee_id   name department   age   salary  experience   city  \
# 9          110   Jack    Finance  38.0  95000.0          12  Delhi
# 3          104  David    Finance  45.0  90000.0          18   Pune
# 6          107  Grace    Finance  41.0  85000.0          15   Pune
#
#   joining_date  performance_score  salary_1  salary_in_lakhs  senior  \
# 9   2014-04-25                9.0   95000.0             0.95    True
# 3   2006-07-01                8.8   90000.0             0.90    True
# 6   2009-05-20                7.8   85000.0             0.85    True
#
#   salary_level      age_cat  joining_yearly  month
# 9         High  Experienced            2014      4
# 3         High  Experienced            2006      7
# 6         High  Experienced            2009      5

# %%
df
# Out:
#    employee_id     name department   age   salary  experience    city  \
# 0          101    Alice         IT  25.0  60000.0           2   Delhi
# 1          102      Bob         HR  32.0  52000.0           8  Mumbai
# 2          103  Charlie         IT  28.0  75000.0           4   Delhi
# 3          104    David    Finance  45.0  90000.0          18    Pune
# 4          105      Eva         HR  29.0  58000.0           5  Mumbai
# 5          106    Frank         IT  35.0  72000.0          10   Delhi
# 6          107    Grace    Finance  41.0  85000.0          15    Pune
# 7          108    Henry         IT  26.0      NaN           3   Delhi
# 8          109      Ivy         HR   NaN  62000.0           6  Mumbai
# 9          110     Jack    Finance  38.0  95000.0          12   Delhi
#
#   joining_date  performance_score  salary_1  salary_in_lakhs  senior  \
# 0   2022-01-15                8.5   60000.0             0.60   False
# ...

# %% [markdown]
# #### Department Highest Salary

# %%
max_sal = df.groupby("department")["salary"].idxmax()

# %%
df.loc[max_sal]
# Out:
#    employee_id     name department   age   salary  experience    city  \
# 9          110     Jack    Finance  38.0  95000.0          12   Delhi
# 8          109      Ivy         HR   NaN  62000.0           6  Mumbai
# 2          103  Charlie         IT  28.0  75000.0           4   Delhi
#
#   joining_date  performance_score  salary_1  salary_in_lakhs  senior  \
# 9   2014-04-25                9.0   95000.0             0.95    True
# 8   2019-08-12                NaN   62000.0             0.62   False
# 2   2021-06-20                9.1   75000.0             0.75   False
#
#   salary_level      age_cat  joining_yearly  month
# 9         High  Experienced            2014      4
# 8       Normal  Experienced            2019      8
# 2       Normal        Young            2021      6

# %%
df.groupby("department").max()
# Out:
#             employee_id   name   age   salary  experience    city  \
# department
# Finance             110   Jack  45.0  95000.0          18    Pune
# HR                  109    Ivy  32.0  62000.0           8  Mumbai
# IT                  108  Henry  35.0  75000.0          10   Delhi
#
#            joining_date  performance_score  salary_1  salary_in_lakhs  senior  \
# department
# Finance      2014-04-25                9.0   95000.0             0.95    True
# HR           2020-02-15                7.2   62000.0             0.62   False
# IT           2023-01-05                9.5   75000.0             0.75    True
#
#            salary_level      age_cat  joining_yearly  month
# department
# Finance            High  Experienced            2014      7
# HR               Normal        Young            2020      8
# IT               Normal        Young            2023     11

# %% [markdown]
# #### Rank()

# %%
df["salary_rank"]=df["salary"].sort_values(ascending=False).rank(method = 'first',
        ascending=False)

# %%
df.sort_values("salary",ascending=False)
# Out:
#    employee_id     name department   age   salary  experience    city  \
# 9          110     Jack    Finance  38.0  95000.0          12   Delhi
# 3          104    David    Finance  45.0  90000.0          18    Pune
# 6          107    Grace    Finance  41.0  85000.0          15    Pune
# 2          103  Charlie         IT  28.0  75000.0           4   Delhi
# 5          106    Frank         IT  35.0  72000.0          10   Delhi
# 8          109      Ivy         HR   NaN  62000.0           6  Mumbai
# 0          101    Alice         IT  25.0  60000.0           2   Delhi
# 4          105      Eva         HR  29.0  58000.0           5  Mumbai
# 1          102      Bob         HR  32.0  52000.0           8  Mumbai
# 7          108    Henry         IT  26.0      NaN           3   Delhi
#
#   joining_date  performance_score  salary_1  salary_in_lakhs  senior  \
# 9   2014-04-25                9.0   95000.0             0.95    True
# ...

# %%
df["avg_salary"] = df.groupby("department")["salary"].transform("mean")
df
# Out:
#    employee_id     name department   age   salary  experience    city  \
# 0          101    Alice         IT  25.0  60000.0           2   Delhi
# 1          102      Bob         HR  32.0  52000.0           8  Mumbai
# 2          103  Charlie         IT  28.0  75000.0           4   Delhi
# 3          104    David    Finance  45.0  90000.0          18    Pune
# 4          105      Eva         HR  29.0  58000.0           5  Mumbai
# 5          106    Frank         IT  35.0  72000.0          10   Delhi
# 6          107    Grace    Finance  41.0  85000.0          15    Pune
# 7          108    Henry         IT  26.0      NaN           3   Delhi
# 8          109      Ivy         HR   NaN  62000.0           6  Mumbai
# 9          110     Jack    Finance  38.0  95000.0          12   Delhi
#
#   joining_date  performance_score  salary_1  salary_in_lakhs  senior  \
# 0   2022-01-15                8.5   60000.0             0.60   False
# ...

# %%
avg = df.groupby("department")["salary"].transform("mean")

# %%
df[df["salary"] > avg ]
# Out:
#    employee_id     name department   age   salary  experience    city  \
# 2          103  Charlie         IT  28.0  75000.0           4   Delhi
# 4          105      Eva         HR  29.0  58000.0           5  Mumbai
# 5          106    Frank         IT  35.0  72000.0          10   Delhi
# 8          109      Ivy         HR   NaN  62000.0           6  Mumbai
# 9          110     Jack    Finance  38.0  95000.0          12   Delhi
#
#   joining_date  performance_score  salary_1  salary_in_lakhs  senior  \
# 2   2021-06-20                9.1   75000.0             0.75   False
# 4   2020-02-15                6.9   58000.0             0.58   False
# 5   2016-11-10                9.5   72000.0             0.72    True
# 8   2019-08-12                NaN   62000.0             0.62   False
# 9   2014-04-25                9.0   95000.0             0.95    True
#
#   salary_level      age_cat  joining_yearly  month  salary_rank    avg_salary
# ...

# %%
df
# Out:
#    employee_id     name department   age   salary  experience    city  \
# 0          101    Alice         IT  25.0  60000.0           2   Delhi
# 1          102      Bob         HR  32.0  52000.0           8  Mumbai
# 2          103  Charlie         IT  28.0  75000.0           4   Delhi
# 3          104    David    Finance  45.0  90000.0          18    Pune
# 4          105      Eva         HR  29.0  58000.0           5  Mumbai
# 5          106    Frank         IT  35.0  72000.0          10   Delhi
# 6          107    Grace    Finance  41.0  85000.0          15    Pune
# 7          108    Henry         IT  26.0      NaN           3   Delhi
# 8          109      Ivy         HR   NaN  62000.0           6  Mumbai
# 9          110     Jack    Finance  38.0  95000.0          12   Delhi
#
#   joining_date  performance_score  salary_1  salary_in_lakhs  senior  \
# 0   2022-01-15                8.5   60000.0             0.60   False
# ...

# %%
pd.pivot_table(
    df,
    values= "salary",
    index="department",
    columns="city",
    aggfunc="mean"
)
# Out:
# city          Delhi        Mumbai     Pune
# department
# Finance     95000.0           NaN  87500.0
# HR              NaN  57333.333333      NaN
# IT          69000.0           NaN      NaN

# %%
df.groupby(["department","city"])["salary"].mean()
# Out:
# department  city
# Finance     Delhi     95000.000000
#             Pune      87500.000000
# HR          Mumbai    57333.333333
# IT          Delhi     69000.000000
# Name: salary, dtype: float64

# %%
scores = pd.DataFrame({
    "name": ["Alice", "Bob", "Charlie"],
    "math": [80, 70, 90],
    "science": [85, 75, 95]
})
scores
# Out:
#       name  math  science
# 0    Alice    80       85
# 1      Bob    70       75
# 2  Charlie    90       95

# %%
pd.melt(
    scores,
    id_vars="name",
    var_name="subjects",
    value_name="score")
# Out:
#       name subjects  score
# 0    Alice     math     80
# 1      Bob     math     70
# 2  Charlie     math     90
# 3    Alice  science     85
# 4      Bob  science     75
# 5  Charlie  science     95

# %%
df
# Out:
#    employee_id     name department   age   salary  experience    city  \
# 0          101    Alice         IT  25.0  60000.0           2   Delhi
# 1          102      Bob         HR  32.0  52000.0           8  Mumbai
# 2          103  Charlie         IT  28.0  75000.0           4   Delhi
# 3          104    David    Finance  45.0  90000.0          18    Pune
# 4          105      Eva         HR  29.0  58000.0           5  Mumbai
# 5          106    Frank         IT  35.0  72000.0          10   Delhi
# 6          107    Grace    Finance  41.0  85000.0          15    Pune
# 7          108    Henry         IT  26.0      NaN           3   Delhi
# 8          109      Ivy         HR   NaN  62000.0           6  Mumbai
# 9          110     Jack    Finance  38.0  95000.0          12   Delhi
#
#   joining_date  performance_score  salary_1  salary_in_lakhs  senior  \
# 0   2022-01-15                8.5   60000.0             0.60   False
# ...

# %% [markdown]
# 26. Find employees satisfying multiple conditions
#
# Question:
#
# Find employees who:
#
# are in Delhi
# have experience > 5
# performance score >= 8

# %%
df[ (df["city"] == "Delhi") &
    (df["experience"] > 5) &
    (df["performance_score"] >= 8) ]
# Out:
#    employee_id   name department   age   salary  experience   city  \
# 5          106  Frank         IT  35.0  72000.0          10  Delhi
# 9          110   Jack    Finance  38.0  95000.0          12  Delhi
#
#   joining_date  performance_score  salary_1  salary_in_lakhs  senior  \
# 5   2016-11-10                9.5   72000.0             0.72    True
# 9   2014-04-25                9.0   95000.0             0.95    True
#
#   salary_level      age_cat  joining_yearly  month  salary_rank  avg_salary
# 5       Normal  Experienced            2016     11          5.0     69000.0
# 9         High  Experienced            2014      4          1.0     90000.0

# %%
df.query("city == 'Delhi' and  experience >5")
# Out:
#    employee_id   name department   age   salary  experience   city  \
# 5          106  Frank         IT  35.0  72000.0          10  Delhi
# 9          110   Jack    Finance  38.0  95000.0          12  Delhi
#
#   joining_date  performance_score  salary_1  salary_in_lakhs  senior  \
# 5   2016-11-10                9.5   72000.0             0.72    True
# 9   2014-04-25                9.0   95000.0             0.95    True
#
#   salary_level      age_cat  joining_yearly  month  salary_rank  avg_salary
# 5       Normal  Experienced            2016     11          5.0     69000.0
# 9         High  Experienced            2014      4          1.0     90000.0

# %% [markdown]
# ### 27. Memory optimization ⭐⭐
#
# Interview question:
#
# You have a DataFrame with 50 million rows. How would you reduce memory usage?

# %%
chunks  = pd.read_csv("tips.csv",chunksize=10)



for chunk in chunks:
    print(chunk)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2
#     total_bill   tip     sex smoker  day    time  size
# 10       10.27  1.71    Male     No  Sun  Dinner     2
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 12       15.42  1.57    Male     No  Sun  Dinner     2
# 13       18.43  3.00    Male     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# ...

# %%
df.info(memory_usage="deep")
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   employee_id        10 non-null     int64
#  1   name               10 non-null     str
#  2   department         10 non-null     str
#  3   age                9 non-null      float64
#  4   salary             9 non-null      float64
#  5   experience         10 non-null     int64
#  6   city               10 non-null     str
#  7   joining_date       10 non-null     datetime64[us]
#  8   performance_score  9 non-null      float64
#  9   salary_1           9 non-null      float64
#  10  salary_in_lakhs    9 non-null      float64
#  11  senior             10 non-null     bool
#  12  salary_level       10 non-null     str
#  13  age_cat            10 non-null     str
#  14  joining_yearly     10 non-null     int32
#  15  month              10 non-null     int32
# ...

# %%
df["salary"] = pd.to_numeric(
    df["age"],
    downcast= 'float'
)

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   employee_id        10 non-null     int64
#  1   name               10 non-null     str
#  2   department         10 non-null     str
#  3   age                9 non-null      float64
#  4   salary             9 non-null      float32
#  5   experience         10 non-null     int64
#  6   city               10 non-null     str
#  7   joining_date       10 non-null     datetime64[us]
#  8   performance_score  9 non-null      float64
#  9   salary_1           9 non-null      float64
#  10  salary_in_lakhs    9 non-null      float64
#  11  senior             10 non-null     bool
#  12  salary_level       10 non-null     str
#  13  age_cat            10 non-null     str
#  14  joining_yearly     10 non-null     int32
#  15  month              10 non-null     int32
# ...

# %% [markdown]
# ### Find the top 2 highest-paid employees from each department, but only consider employees with at least 5 years of experience.

# %%
df
# Out:
#    employee_id     name department   age   salary  experience    city  \
# 0          101    Alice         IT  25.0  60000.0           2   Delhi
# 1          102      Bob         HR  32.0  52000.0           8  Mumbai
# 2          103  Charlie         IT  28.0  75000.0           4   Delhi
# 3          104    David    Finance  45.0  90000.0          18    Pune
# 4          105      Eva         HR  29.0  58000.0           5  Mumbai
# 5          106    Frank         IT  35.0  72000.0          10   Delhi
# 6          107    Grace    Finance  41.0  85000.0          15    Pune
# 7          108    Henry         IT  26.0      NaN           3   Delhi
# 8          109      Ivy         HR   NaN  62000.0           6  Mumbai
# 9          110     Jack    Finance  38.0  95000.0          12   Delhi
#
#   joining_date  performance_score
# 0   2022-01-15                8.5
# 1   2018-03-10                7.2
# 2   2021-06-20                9.1
# 3   2006-07-01                8.8
# ...

# %%
df[df["experience"] >5 ].sort_values("salary",ascending=False).groupby("department")

# %%
pd.Da
